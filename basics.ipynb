# %% [markdown]
# ### documentation

# %% [markdown]
# #### [Muse LSL documentation](https://github.com/alexandrebarachant/muse-lsl)
# #### [Lab Streaming Layer documentation](https://github.com/sccn/labstreaminglayer?fbclid=IwAR15C2bm4Dv-B6fuhMW7T3SsOx2lxeTTWDdjhYVc1aSDCJjg1lNbdzOFDV4)
# #### [notebook experiments](https://eeg-notebooks.readthedocs.io/en/latest/getting_started.html)

# %% [markdown]
# ### install requirements

# %% [markdown]
# ```>>> pip install muselsl```
#
# ```>>> sudo apt-get install libpcap-dev```
#
# ```>>> sudo setcap 'cap_net_raw,cap_net_admin+eip' `which hcitool` ```

# %% [markdown]
# ### import packages

# %%
import pandas as pd
from muselsl import view
from matplotlib import pyplot as plt
import matplotlib

# %%
matplotlib.rcParams["figure.figsize"] = [15, 8]

# %% [markdown]
# ### start and record stream from command line

# %% [markdown]
# ```>>> muselsl stream -a 00:55:DA:B5:85:4C```
#
# ```>>> muselsl record -d 60 -f ./<file_name>.csv```

# %% [markdown]
# ### visualize real-time recording

# %%
view(version=1, backend="nbAgg", figure='15x10')
# Out:
# Looking for an EEG stream...
# Start acquiring data.
# <img src="data:image/png;base64,..." width="1080">

# %% [markdown]
# ### read recorded data

# %%
data = pd.read_csv("test_09_30.csv")

# %%
channel_dict = {"AF7": "red", "AF8": "orange", "TP9": "green", "TP10": "blue"}

# %%
for channel, color in channel_dict.items():

    plt.plot(
        data.loc[5000:6000, "timestamps"].values,
        data.loc[5000:6000, channel].values,
        c=color,
        label=channel,
    )

plt.title("EEG data")
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="1080">
